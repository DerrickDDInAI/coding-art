# %% [markdown]
# # Extract Background
#
# ## Sources:
# - [google colab](https://colab.research.google.com/drive/194DC_lyCRafwlJZ5DyRwrK9Gh2RCciVT?usp=sharing)

# %% [markdown]
# ## Import modules

# %%
# import internal modules
# from typing import List, Set, Dict, TypedDict, Tuple, Optional, Union
from pathlib import Path
from datetime import date


# import 3rd-party modules
import cv2
import numpy as np

# %% [markdown]
# ## Compute average of frame
# The logic:
# - works when camera doesn't move
# - background is fixed and the foreground (like cars or people) is moving and is considered as noise
# - => to remove noise, compute the average

# %%
# set video path
filepath = Path("/Users/derrickvanfrausum/BeCode_AI/git-repos/learn-ai/opencv/assets/videos/DJI_0113.MP4")

# initialize video stream
cap = cv2.VideoCapture(str(filepath))

# get frame indexes
frame_indexes = np.linspace(0, cap.get(cv2.CAP_PROP_FRAME_COUNT) - 1, 100)
# frame_indexes = cap.get(cv2.CAP_PROP_FRAME_COUNT) * np.random.uniform(size=100)

# create empty list of frames
frames = []

# iterate over frame indexes
for frame_idx in frame_indexes:
    # set frame position to the index
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)

    # read frame
    ret, frame = cap.read()

    if ret:

        # append frame to list of frames
        frames.append(frame)

# compute average of frames
# bg_frame = np.mean(frames, axis=0).astype(dtype=np.uint8)
bg_frame = np.median(frames, axis=0).astype(dtype=np.uint8)

# save image
# get current date
today = date.today().strftime("%Y%m%d")

# set output image path
bg_frame_path = f"assets/images/bg_extracter/bg_extracter_{filepath.stem}_{today}_linspace.jpg"

# save output image
cv2.imwrite(bg_frame_path, bg_frame)

# release video stream
cap.release()
