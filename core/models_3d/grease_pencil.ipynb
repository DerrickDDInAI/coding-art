# %%
import numpy as np

# %%
points = np.array([[0,0,0], [1,1,0]])
for i in points:
    print(i)
# Out:
# [0 0 0]
# [1 1 0]

# %%
from pathlib import Path

# %%
# Out:
# PosixPath('/Users/derrickvanfrausum/BeCode_AI/git-repos/coding-art/core')

# %% [markdown]
# Thanks for the article!
# I've just started Blender and this is very useful and cool!! 🤯
# I'm using Blender 3.2.1 on macOS and I had to make a few changes to the code to make this work:
#
# - In get_grease_pencil function, from:
# bpy.ops.object.gpencil_add(view_align=False, location=(0, 0, 0), type='EMPTY')
# To:
# bpy.ops.object.gpencil_add(align="WORLD", location=(0, 0, 0), type='EMPTY')
# * align argument can take these strings: 'WORLD', 'VIEW', 'CURSOR'
#
# - In draw_circle fct, from:
# gp_stroke.draw_cyclic = True
# To:
# gp_stroke.use_cyclic = True
#
# - I'm not sure for this: in draw_sphere fct, from:
# angle = math.pi / circles
# To:
# angle = 2 * math.pi / circles
